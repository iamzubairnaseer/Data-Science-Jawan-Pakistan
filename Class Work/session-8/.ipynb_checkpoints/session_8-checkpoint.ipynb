# %%
import pandas as pd

# %%
dir(pd)
# Out:
# ['ArrowDtype',
#  'BooleanDtype',
#  'Categorical',
#  'CategoricalDtype',
#  'CategoricalIndex',
#  'DataFrame',
#  'DateOffset',
#  'DatetimeIndex',
#  'DatetimeTZDtype',
#  'ExcelFile',
#  'ExcelWriter',
#  'Flags',
#  'Float32Dtype',
#  'Float64Dtype',
#  'Grouper',
#  'HDFStore',
#  'Index',
#  'IndexSlice',
#  'Int16Dtype',
#  'Int32Dtype',
#  'Int64Dtype',
#  'Int8Dtype',
#  'Interval',
#  'IntervalDtype',
#  'IntervalIndex',
#  'MultiIndex',
#  'NA',
#  'NaT',
#  'NamedAgg',
#  'Period',
#  'PeriodDtype',
#  'PeriodIndex',
#  'RangeIndex',
#  'Series',
#  'SparseDtype',
#  'StringDtype',
#  'Timedelta',
#  'TimedeltaIndex',
#  'Timestamp',
#  'UInt16Dtype',
#  'UInt32Dtype',
#  'UInt64Dtype',
#  'UInt8Dtype',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__docformat__',
#  '__file__',
#  '__git_version__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '_built_with_meson',
#  '_config',
# ...

# %%
df = pd.read_csv('./Session 8.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %% [markdown]
# Single column = series;
# multiple rows and column = data frame

# %%
df['Ship Mode']
# Out:
# 0         Second Class
# 1         Second Class
# 2         Second Class
# 3       Standard Class
# 4       Standard Class
#              ...
# 9989      Second Class
# 9990    Standard Class
# 9991    Standard Class
# 9992    Standard Class
# 9993      Second Class
# Name: Ship Mode, Length: 9994, dtype: object

# %%
df['Ship Mode'].astype('string')
# Out:
# 0         Second Class
# 1         Second Class
# 2         Second Class
# 3       Standard Class
# 4       Standard Class
#              ...
# 9989      Second Class
# 9990    Standard Class
# 9991    Standard Class
# 9992    Standard Class
# 9993      Second Class
# Name: Ship Mode, Length: 9994, dtype: string

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %%
df['Ship Mode'] = df['Ship Mode'].astype('string')

# %%
df['Segment'] = df['Segment'].astype('string')

# %%
df['Country'] = df['Country'].astype('string')

# %%
df['City'] = df['City'].astype('string')

# %%
df['State'] = df['State'].astype('string')

# %%
df['Postal Code'] = df['Postal Code'].astype('string')

# %%
df['Region'] = df['Region'].astype('string')

# %%
df['Category'] = df['Category'].astype('string')

# %%
df['Sub-Category'] = df['Sub-Category'].astype('string')

# %%
df['Sales'] = df['Sales'].astype('string')

# %%
df['Quantity'] = df['Quantity'].astype('string')

# %%
df['Discount'] = df['Discount'].astype('string')

# %%
df['Profit'] = df['Profit'].astype('string')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   string
#  1   Segment       9994 non-null   string
#  2   Country       9994 non-null   string
#  3   City          9994 non-null   string
#  4   State         9994 non-null   string
#  5   Postal Code   9994 non-null   string
#  6   Region        9994 non-null   string
#  7   Category      9994 non-null   string
#  8   Sub-Category  9994 non-null   string
#  9   Sales         9994 non-null   string
#  10  Quantity      9994 non-null   string
#  11  Discount      9994 non-null   string
#  12  Profit        9994 non-null   string
# dtypes: string(13)
# memory usage: 1015.1 KB

# %%
df.dtypes
# Out:
# Ship Mode       string[python]
# Segment         string[python]
# Country         string[python]
# City            string[python]
# State           string[python]
# Postal Code     string[python]
# Region          string[python]
# Category        string[python]
# Sub-Category    string[python]
# Sales           string[python]
# Quantity        string[python]
# Discount        string[python]
# Profit          string[python]
# dtype: object

# %%
df['Sales'] = df['Sales'].astype('float64')

# %%
df['Profit'] = df['Profit'].astype('float64')

# %%
df['Discount'] = df['Discount'].astype('float64')

# %%
df['Quantity'] = df['Quantity'].astype('int64')

# %%
df.dtypes
# Out:
# Ship Mode       string[python]
# Segment         string[python]
# Country         string[python]
# City            string[python]
# State           string[python]
# Postal Code     string[python]
# Region          string[python]
# Category        string[python]
# Sub-Category    string[python]
# Sales                  float64
# Quantity                 int64
# Discount               float64
# Profit                 float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   string
#  1   Segment       9994 non-null   string
#  2   Country       9994 non-null   string
#  3   City          9994 non-null   string
#  4   State         9994 non-null   string
#  5   Postal Code   9994 non-null   string
#  6   Region        9994 non-null   string
#  7   Category      9994 non-null   string
#  8   Sub-Category  9994 non-null   string
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(1), string(9)
# memory usage: 1015.1 KB

# %%
df.shape
# Out:
# (9994, 13)

# %%
df.loc[3]
# Out:
# Ship Mode        Standard Class
# Segment                Consumer
# Country           United States
# City            Fort Lauderdale
# State                   Florida
# Postal Code               33311
# Region                    South
# Category              Furniture
# Sub-Category             Tables
# Sales                  957.5775
# Quantity                      5
# Discount                   0.45
# Profit                 -383.031
# Name: 3, dtype: object

# %%
df.loc[3]['Segment']
# Out:
# 'Consumer'

# %%
df.loc[3, 'Segment']
# Out:
# 'Consumer'

# %%
df.iloc[3]
# Out:
# Ship Mode        Standard Class
# Segment                Consumer
# Country           United States
# City            Fort Lauderdale
# State                   Florida
# Postal Code               33311
# Region                    South
# Category              Furniture
# Sub-Category             Tables
# Sales                  957.5775
# Quantity                      5
# Discount                   0.45
# Profit                 -383.031
# Name: 3, dtype: object

# %%
df.iloc[3, 1]
# Out:
# 'Consumer'

# %%
df.iloc[3][1]
# Out:
# C:\Users\Zubair Naseer\AppData\Local\Temp\ipykernel_21328\3292216812.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   df.iloc[3][1]
# 'Consumer'

# %%
df.loc[2:10]
# Out:
#          Ship Mode    Segment        Country             City       State  \
# 2     Second Class  Corporate  United States      Los Angeles  California
# 3   Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4   Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 5   Standard Class   Consumer  United States      Los Angeles  California
# 6   Standard Class   Consumer  United States      Los Angeles  California
# 7   Standard Class   Consumer  United States      Los Angeles  California
# 8   Standard Class   Consumer  United States      Los Angeles  California
# 9   Standard Class   Consumer  United States      Los Angeles  California
# 10  Standard Class   Consumer  United States      Los Angeles  California
#
#    Postal Code Region         Category Sub-Category      Sales  Quantity  \
# 2        90036   West  Office Supplies       Labels    14.6200         2
# 3        33311  South        Furniture       Tables   957.5775         5
# ...

# %%
df.iloc[2:10]
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 5  Standard Class   Consumer  United States      Los Angeles  California
# 6  Standard Class   Consumer  United States      Los Angeles  California
# 7  Standard Class   Consumer  United States      Los Angeles  California
# 8  Standard Class   Consumer  United States      Los Angeles  California
# 9  Standard Class   Consumer  United States      Los Angeles  California
#
#   Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 2       90036   West  Office Supplies       Labels   14.6200         2
# 3       33311  South        Furniture       Tables  957.5775         5
# 4       33311  South  Office Supplies      Storage   22.3680         2
# ...

# %%
df.iloc[2:10, 1:-3]
# Out:
#      Segment        Country             City       State Postal Code Region  \
# 2  Corporate  United States      Los Angeles  California       90036   West
# 3   Consumer  United States  Fort Lauderdale     Florida       33311  South
# 4   Consumer  United States  Fort Lauderdale     Florida       33311  South
# 5   Consumer  United States      Los Angeles  California       90032   West
# 6   Consumer  United States      Los Angeles  California       90032   West
# 7   Consumer  United States      Los Angeles  California       90032   West
# 8   Consumer  United States      Los Angeles  California       90032   West
# 9   Consumer  United States      Los Angeles  California       90032   West
#
#           Category Sub-Category     Sales
# 2  Office Supplies       Labels   14.6200
# 3        Furniture       Tables  957.5775
# 4  Office Supplies      Storage   22.3680
# 5        Furniture  Furnishings   48.8600
# 6  Office Supplies          Art    7.2800
# ...

# %%
df.iloc[2:10, 1:10]
# Out:
#      Segment        Country             City       State Postal Code Region  \
# 2  Corporate  United States      Los Angeles  California       90036   West
# 3   Consumer  United States  Fort Lauderdale     Florida       33311  South
# 4   Consumer  United States  Fort Lauderdale     Florida       33311  South
# 5   Consumer  United States      Los Angeles  California       90032   West
# 6   Consumer  United States      Los Angeles  California       90032   West
# 7   Consumer  United States      Los Angeles  California       90032   West
# 8   Consumer  United States      Los Angeles  California       90032   West
# 9   Consumer  United States      Los Angeles  California       90032   West
#
#           Category Sub-Category     Sales
# 2  Office Supplies       Labels   14.6200
# 3        Furniture       Tables  957.5775
# 4  Office Supplies      Storage   22.3680
# 5        Furniture  Furnishings   48.8600
# 6  Office Supplies          Art    7.2800
# ...

# %%
df.loc[2:9, 'Segment':'Sales']
# Out:
#      Segment        Country             City       State Postal Code Region  \
# 2  Corporate  United States      Los Angeles  California       90036   West
# 3   Consumer  United States  Fort Lauderdale     Florida       33311  South
# 4   Consumer  United States  Fort Lauderdale     Florida       33311  South
# 5   Consumer  United States      Los Angeles  California       90032   West
# 6   Consumer  United States      Los Angeles  California       90032   West
# 7   Consumer  United States      Los Angeles  California       90032   West
# 8   Consumer  United States      Los Angeles  California       90032   West
# 9   Consumer  United States      Los Angeles  California       90032   West
#
#           Category Sub-Category     Sales
# 2  Office Supplies       Labels   14.6200
# 3        Furniture       Tables  957.5775
# 4  Office Supplies      Storage   22.3680
# 5        Furniture  Furnishings   48.8600
# 6  Office Supplies          Art    7.2800
# ...

# %% [markdown]
# In df.loc[] both indexes are included
# In df.iloc[] last index is excluded

# %%
# state, sales, quantity
df.loc[2:9, ['State', 'Sales', 'Quantity']]
# Out:
#         State     Sales  Quantity
# 2  California   14.6200         2
# 3     Florida  957.5775         5
# 4     Florida   22.3680         2
# 5  California   48.8600         7
# 6  California    7.2800         4
# 7  California  907.1520         6
# 8  California   18.5040         3
# 9  California  114.9000         5

# %%
df.iloc[2:10, [4, 9, 10]]
# Out:
#         State     Sales  Quantity
# 2  California   14.6200         2
# 3     Florida  957.5775         5
# 4     Florida   22.3680         2
# 5  California   48.8600         7
# 6  California    7.2800         4
# 7  California  907.1520         6
# 8  California   18.5040         3
# 9  California  114.9000         5

# %% [markdown]
# ### not ---> ~
# ### or ---> |
# ### and ---> &

# %% [markdown]
# # simd = single instruction for multiple data

# %%
df['Region'].unique()
# Out:
# <StringArray>
# ['South', 'West', 'Central', 'East']
# Length: 4, dtype: string

# %%
df['Region'] == 'South'
# Out:
# 0        True
# 1        True
# 2       False
# 3        True
# 4        True
#         ...
# 9989     True
# 9990    False
# 9991    False
# 9992    False
# 9993    False
# Name: Region, Length: 9994, dtype: boolean

# %%
df[df['Region'] == 'South']
# Out:
#            Ship Mode      Segment        Country             City  \
# 0       Second Class     Consumer  United States        Henderson
# 1       Second Class     Consumer  United States        Henderson
# 3     Standard Class     Consumer  United States  Fort Lauderdale
# 4     Standard Class     Consumer  United States  Fort Lauderdale
# 12    Standard Class     Consumer  United States          Concord
# ...              ...          ...            ...              ...
# 9971  Standard Class  Home Office  United States           Smyrna
# 9980    Second Class     Consumer  United States        Lafayette
# 9987  Standard Class    Corporate  United States           Athens
# 9988  Standard Class    Corporate  United States           Athens
# 9989    Second Class     Consumer  United States            Miami
#
#                State Postal Code Region         Category Sub-Category  \
# 0           Kentucky       42420  South        Furniture    Bookcases
# ...

# %%
df[df['Sales'] > 200]
# Out:
#            Ship Mode      Segment        Country             City       State  \
# 0       Second Class     Consumer  United States        Henderson    Kentucky
# 1       Second Class     Consumer  United States        Henderson    Kentucky
# 3     Standard Class     Consumer  United States  Fort Lauderdale     Florida
# 7     Standard Class     Consumer  United States      Los Angeles  California
# 10    Standard Class     Consumer  United States      Los Angeles  California
# ...              ...          ...            ...              ...         ...
# 9976  Standard Class  Home Office  United States      Los Angeles  California
# 9979  Standard Class  Home Office  United States      Los Angeles  California
# 9988  Standard Class    Corporate  United States           Athens     Georgia
# 9991  Standard Class     Consumer  United States       Costa Mesa  California
# 9993    Second Class     Consumer  United States      Westminster  California
#
# ...

# %%
(df['Sales'] > 200) & (df['Region'] == 'South')
# Out:
# 0        True
# 1        True
# 2       False
# 3        True
# 4       False
#         ...
# 9989    False
# 9990    False
# 9991    False
# 9992    False
# 9993    False
# Length: 9994, dtype: boolean

# %%
df[(df['Sales'] > 200) & (df['Region'] == 'South')]
# Out:
#            Ship Mode      Segment        Country              City  \
# 0       Second Class     Consumer  United States         Henderson
# 1       Second Class     Consumer  United States         Henderson
# 3     Standard Class     Consumer  United States   Fort Lauderdale
# 72    Standard Class     Consumer  United States           Memphis
# 79       First Class    Corporate  United States           Decatur
# ...              ...          ...            ...               ...
# 9769  Standard Class  Home Office  United States           Hialeah
# 9816  Standard Class    Corporate  United States  Saint Petersburg
# 9829  Standard Class     Consumer  United States         Charlotte
# 9882     First Class     Consumer  United States         Woodstock
# 9988  Standard Class    Corporate  United States            Athens
#
#                State Postal Code Region         Category Sub-Category  \
# 0           Kentucky       42420  South        Furniture    Bookcases
# ...

# %%
pd.options.display.max_rows = None # = 100 means 100 rows

# %%
df[(df['Sales'] > 200) & (df['Region'] == 'South')]
# Out:
#            Ship Mode      Segment        Country              City  \
# 0       Second Class     Consumer  United States         Henderson
# 1       Second Class     Consumer  United States         Henderson
# 3     Standard Class     Consumer  United States   Fort Lauderdale
# 72    Standard Class     Consumer  United States           Memphis
# 79       First Class    Corporate  United States           Decatur
# 83    Standard Class    Corporate  United States            Durham
# 85      Second Class     Consumer  United States          Columbia
# 182     Second Class  Home Office  United States            Monroe
# 229   Standard Class     Consumer  United States          Columbia
# 231   Standard Class  Home Office  United States             Tampa
# 232   Standard Class  Home Office  United States             Tampa
# 234   Standard Class  Home Office  United States             Tampa
# 235   Standard Class  Home Office  United States             Tampa
# ...

# %%
pd.options.display.max_rows = 10 # = 100 means 100 rows

# %%
df[(df['Sales'] > 200) & (df['Region'] == 'South')]
# Out:
#            Ship Mode      Segment        Country              City  \
# 0       Second Class     Consumer  United States         Henderson
# 1       Second Class     Consumer  United States         Henderson
# 3     Standard Class     Consumer  United States   Fort Lauderdale
# 72    Standard Class     Consumer  United States           Memphis
# 79       First Class    Corporate  United States           Decatur
# ...              ...          ...            ...               ...
# 9769  Standard Class  Home Office  United States           Hialeah
# 9816  Standard Class    Corporate  United States  Saint Petersburg
# 9829  Standard Class     Consumer  United States         Charlotte
# 9882     First Class     Consumer  United States         Woodstock
# 9988  Standard Class    Corporate  United States            Athens
#
#                State Postal Code Region         Category Sub-Category  \
# 0           Kentucky       42420  South        Furniture    Bookcases
# ...

# %%
df[(df['Sales'] > 200) & ((df['Region'] == 'South') | (df['Region'] == 'West'))]
# Out:
#            Ship Mode      Segment        Country             City       State  \
# 0       Second Class     Consumer  United States        Henderson    Kentucky
# 1       Second Class     Consumer  United States        Henderson    Kentucky
# 3     Standard Class     Consumer  United States  Fort Lauderdale     Florida
# 7     Standard Class     Consumer  United States      Los Angeles  California
# 10    Standard Class     Consumer  United States      Los Angeles  California
# ...              ...          ...            ...              ...         ...
# 9976  Standard Class  Home Office  United States      Los Angeles  California
# 9979  Standard Class  Home Office  United States      Los Angeles  California
# 9988  Standard Class    Corporate  United States           Athens     Georgia
# 9991  Standard Class     Consumer  United States       Costa Mesa  California
# 9993    Second Class     Consumer  United States      Westminster  California
#
# ...

# %%
df[(df['Sales'] > 200) & (~(df['Region'] == 'South') | (df['Region'] == 'West'))]
# Out:
#            Ship Mode      Segment        Country         City       State  \
# 7     Standard Class     Consumer  United States  Los Angeles  California
# 10    Standard Class     Consumer  United States  Los Angeles  California
# 11    Standard Class     Consumer  United States  Los Angeles  California
# 13    Standard Class     Consumer  United States      Seattle  Washington
# 16    Standard Class     Consumer  United States      Madison   Wisconsin
# ...              ...          ...            ...          ...         ...
# 9973  Standard Class  Home Office  United States  Los Angeles  California
# 9976  Standard Class  Home Office  United States  Los Angeles  California
# 9979  Standard Class  Home Office  United States  Los Angeles  California
# 9991  Standard Class     Consumer  United States   Costa Mesa  California
# 9993    Second Class     Consumer  United States  Westminster  California
#
#      Postal Code   Region         Category Sub-Category     Sales  Quantity  \
# ...

# %%
df[(df['Sales'] > 200) & ~((df['Region'] == 'South') | (df['Region'] == 'West'))]
# Out:
#            Ship Mode      Segment        Country          City         State  \
# 16    Standard Class     Consumer  United States       Madison     Wisconsin
# 27    Standard Class     Consumer  United States  Philadelphia  Pennsylvania
# 35       First Class    Corporate  United States    Richardson         Texas
# 38    Standard Class  Home Office  United States       Houston         Texas
# 39    Standard Class  Home Office  United States       Houston         Texas
# ...              ...          ...            ...           ...           ...
# 9947    Second Class    Corporate  United States  Indianapolis       Indiana
# 9948    Second Class    Corporate  United States  Indianapolis       Indiana
# 9957  Standard Class  Home Office  United States  New Rochelle      New York
# 9962     First Class  Home Office  United States       Houston         Texas
# 9968  Standard Class     Consumer  United States    Plainfield    New Jersey
#
# ...

# %%
df[['Region', 'Sales']]
# Out:
#      Region     Sales
# 0     South  261.9600
# 1     South  731.9400
# 2      West   14.6200
# 3     South  957.5775
# 4     South   22.3680
# ...     ...       ...
# 9989  South   25.2480
# 9990   West   91.9600
# 9991   West  258.5760
# 9992   West   29.6000
# 9993   West  243.1600
#
# [9994 rows x 2 columns]

# %%
df.describe()
# Out:
#               Sales     Quantity     Discount       Profit
# count   9994.000000  9994.000000  9994.000000  9994.000000
# mean     229.858001     3.789574     0.156203    28.656896
# std      623.245101     2.225110     0.206452   234.260108
# min        0.444000     1.000000     0.000000 -6599.978000
# 25%       17.280000     2.000000     0.000000     1.728750
# 50%       54.490000     3.000000     0.200000     8.666500
# 75%      209.940000     5.000000     0.200000    29.364000
# max    22638.480000    14.000000     0.800000  8399.976000

# %%
df.describe(include='all')
# Out:
#              Ship Mode   Segment        Country           City       State  \
# count             9994      9994           9994           9994        9994
# unique               4         3              1            531          49
# top     Standard Class  Consumer  United States  New York City  California
# freq              5968      5191           9994            915        2001
# mean               NaN       NaN            NaN            NaN         NaN
# ...                ...       ...            ...            ...         ...
# min                NaN       NaN            NaN            NaN         NaN
# 25%                NaN       NaN            NaN            NaN         NaN
# 50%                NaN       NaN            NaN            NaN         NaN
# 75%                NaN       NaN            NaN            NaN         NaN
# max                NaN       NaN            NaN            NaN         NaN
#
# ...

# %%
df.loc[
    (df['Sales'] > 200) & ~((df['Region'] == 'South') | (df['Region'] == 'West')),
    ['Region', 'Sales']
]
# Out:
#        Region      Sales
# 16    Central   665.8800
# 27       East  3083.4300
# 35    Central  1097.5440
# 38    Central   532.3992
# 39    Central   212.0580
# ...       ...        ...
# 9947  Central  1925.8800
# 9948  Central  2405.2000
# 9957     East   223.9200
# 9962  Central   383.4656
# 9968     East   735.9800
#
# [1310 rows x 2 columns]
