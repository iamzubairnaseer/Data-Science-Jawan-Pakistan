# %%
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('cars.csv')

# %%
df
# Out:
#           Make       Model  Year                Engine Fuel Type  Engine HP  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series  2011     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# ...        ...         ...   ...                             ...        ...
# 11909    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura         ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln      Zephyr  2006                regular unleaded      221.0
#
# ...

# %%
df.isnull().sum()
# Out:
# Make                    0
# Model                   0
# Year                    0
# Engine Fuel Type        3
# Engine HP              69
# Engine Cylinders       30
# Transmission Type       0
# Driven_Wheels           0
# Number of Doors         6
# Market Category      3742
# Vehicle Size            0
# Vehicle Style           0
# highway MPG             0
# city mpg                0
# Popularity              0
# MSRP                    0
# dtype: int64

# %%
df.dtypes
# Out:
# Make                  object
# Model                 object
# Year                   int64
# Engine Fuel Type      object
# Engine HP            float64
# Engine Cylinders     float64
# Transmission Type     object
# Driven_Wheels         object
# Number of Doors      float64
# Market Category       object
# Vehicle Size          object
# Vehicle Style         object
# highway MPG            int64
# city mpg               int64
# Popularity             int64
# MSRP                   int64
# dtype: object

# %%
df['Engine Fuel Type'].unique()
# Out:
# array(['premium unleaded (required)', 'regular unleaded',
#        'premium unleaded (recommended)', 'flex-fuel (unleaded/E85)',
#        'diesel', 'electric',
#        'flex-fuel (premium unleaded recommended/E85)', 'natural gas',
#        'flex-fuel (premium unleaded required/E85)',
#        'flex-fuel (unleaded/natural gas)', nan], dtype=object)

# %%
df['Engine Fuel Type'].mode()
# Out:
# 0    regular unleaded
# Name: Engine Fuel Type, dtype: object

# %%
df['Engine Fuel Type'].fillna(df['Engine Fuel Type'].mode()[0], inplace=True)

# %%
df.isnull().sum()
# Out:
# Make                    0
# Model                   0
# Year                    0
# Engine Fuel Type        0
# Engine HP              69
# Engine Cylinders       30
# Transmission Type       0
# Driven_Wheels           0
# Number of Doors         6
# Market Category      3742
# Vehicle Size            0
# Vehicle Style           0
# highway MPG             0
# city mpg                0
# Popularity              0
# MSRP                    0
# dtype: int64

# %%
df['Engine Fuel Type'].nunique() # number of unique values
# Out:
# 10

# %%
df['Engine Fuel Type'].value_counts().head()
# Out:
# Engine Fuel Type
# regular unleaded                  7175
# premium unleaded (required)       2009
# premium unleaded (recommended)    1523
# flex-fuel (unleaded/E85)           899
# diesel                             154
# Name: count, dtype: int64

# %%
df['Engine Fuel Type'].value_counts()
# Out:
# Engine Fuel Type
# regular unleaded                                7175
# premium unleaded (required)                     2009
# premium unleaded (recommended)                  1523
# flex-fuel (unleaded/E85)                         899
# diesel                                           154
# electric                                          66
# flex-fuel (premium unleaded required/E85)         54
# flex-fuel (premium unleaded recommended/E85)      26
# flex-fuel (unleaded/natural gas)                   6
# natural gas                                        2
# Name: count, dtype: int64

# %%
df['Engine HP'].unique()
# Out:
# array([ 335.,  300.,  230.,  320.,  172.,  160.,  130.,  158.,  240.,
#         248.,  162.,  217.,  184.,  295.,  115.,  140.,  155.,  114.,
#         100.,  241.,  180.,  177.,  228.,  121.,  148.,  194.,  218.,
#         161.,  292.,  250.,  255.,  222.,   82.,  134.,  306.,  400.,
#         425.,  350.,  332.,  268.,  282.,  275.,  201.,  442.,  562.,
#         597.,  237.,  270.,  445.,  443.,  302.,  322.,  315.,   nan,
#         101.,  135.,  485.,  238.,  515.,  543.,  631.,  604.,  620.,
#         611.,  661.,  157.,  402.,  389.,  110.,  532.,  170.,  165.,
#         125.,  641.,  535.,  153.,  144.,  188.,  372.,  108.,  168.,
#         190.,  205.,  200.,  227.,  173.,  220.,  210.,  280.,  207.,
#         265.,  260.,  290.,  285.,  390.,  225.,  185.,  150.,  430.,
#         520.,  560.,  475.,  500.,  540.,  370.,  580.,  420.,  345.,
#         195.,  193.,  208.,  181.,  236.,  186.,  252.,  310.,  333.,
# ...

# %%
df['Engine HP'].nunique()
# Out:
# 356

# %%
df['Engine HP'].median()
# Out:
# 227.0

# %%
df['Engine HP'].mode()
# Out:
# 0    200.0
# Name: Engine HP, dtype: float64

# %%
df['Engine HP'].value_counts()
# Out:
# Engine HP
# 200.0    456
# 170.0    351
# 210.0    320
# 240.0    268
# 285.0    246
#         ...
# 660.0      1
# 661.0      1
# 573.0      1
# 592.0      1
# 154.0      1
# Name: count, Length: 356, dtype: int64

# %%
df['Engine HP'].fillna(df['Engine HP'].median(), inplace=True)

# %%
df['Engine HP'].mean()
# Out:
# np.float64(249.2564210172906)

# %%
df.isnull().sum()
# Out:
# Make                    0
# Model                   0
# Year                    0
# Engine Fuel Type        0
# Engine HP               0
# Engine Cylinders       30
# Transmission Type       0
# Driven_Wheels           0
# Number of Doors         6
# Market Category      3742
# Vehicle Size            0
# Vehicle Style           0
# highway MPG             0
# city mpg                0
# Popularity              0
# MSRP                    0
# dtype: int64

# %%
df['Engine Cylinders'].fillna(df['Engine Cylinders'].median(), inplace=True)

# %%
df['Number of Doors'].fillna(df['Number of Doors'].mode()[0], inplace=True)

# %%
df.isnull().sum()
# Out:
# Make                    0
# Model                   0
# Year                    0
# Engine Fuel Type        0
# Engine HP               0
# Engine Cylinders        0
# Transmission Type       0
# Driven_Wheels           0
# Number of Doors         0
# Market Category      3742
# Vehicle Size            0
# Vehicle Style           0
# highway MPG             0
# city mpg                0
# Popularity              0
# MSRP                    0
# dtype: int64

# %%
df.drop(columns=['Market Category'], inplace=True)

# %%
df.isnull().sum()
# Out:
# Make                 0
# Model                0
# Year                 0
# Engine Fuel Type     0
# Engine HP            0
# Engine Cylinders     0
# Transmission Type    0
# Driven_Wheels        0
# Number of Doors      0
# Vehicle Size         0
# Vehicle Style        0
# highway MPG          0
# city mpg             0
# Popularity           0
# MSRP                 0
# dtype: int64

# %%
df.count()
# Out:
# Make                 11914
# Model                11914
# Year                 11914
# Engine Fuel Type     11914
# Engine HP            11914
# Engine Cylinders     11914
# Transmission Type    11914
# Driven_Wheels        11914
# Number of Doors      11914
# Vehicle Size         11914
# Vehicle Style        11914
# highway MPG          11914
# city mpg             11914
# Popularity           11914
# MSRP                 11914
# dtype: int64

# %%
df.dropna()
# Out:
#           Make       Model  Year                Engine Fuel Type  Engine HP  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series  2011     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# ...        ...         ...   ...                             ...        ...
# 11909    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura         ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln      Zephyr  2006                regular unleaded      221.0
#
# ...

# %%
df.count()
# Out:
# Make                 11914
# Model                11914
# Year                 11914
# Engine Fuel Type     11914
# Engine HP            11914
# Engine Cylinders     11914
# Transmission Type    11914
# Driven_Wheels        11914
# Number of Doors      11914
# Vehicle Size         11914
# Vehicle Style        11914
# highway MPG          11914
# city mpg             11914
# Popularity           11914
# MSRP                 11914
# dtype: int64

# %%
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 11909    False
# 11910    False
# 11911    False
# 11912    False
# 11913    False
# Length: 11914, dtype: bool

# %%
df.duplicated().sum()
# Out:
# np.int64(720)

# %%
df.drop_duplicates(inplace=True)

# %%
df.count()
# Out:
# Make                 11194
# Model                11194
# Year                 11194
# Engine Fuel Type     11194
# Engine HP            11194
# Engine Cylinders     11194
# Transmission Type    11194
# Driven_Wheels        11194
# Number of Doors      11194
# Vehicle Size         11194
# Vehicle Style        11194
# highway MPG          11194
# city mpg             11194
# Popularity           11194
# MSRP                 11194
# dtype: int64

# %%
df
# Out:
#           Make       Model  Year                Engine Fuel Type  Engine HP  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series  2011     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# ...        ...         ...   ...                             ...        ...
# 11909    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura         ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln      Zephyr  2006                regular unleaded      221.0
#
# ...

# %%
df['Make'].value_counts()
# Out:
# Make
# Chevrolet        1083
# Ford              824
# Toyota            716
# Volkswagen        568
# Nissan            551
# Dodge             528
# GMC               482
# Honda             433
# Mazda             412
# Cadillac          396
# Suzuki            342
# Mercedes-Benz     341
# Infiniti          328
# BMW               324
# Audi              321
# Volvo             266
# Hyundai           259
# Acura             246
# Subaru            239
# Kia               229
# Mitsubishi        208
# Lexus             202
# Buick             190
# Chrysler          187
# Pontiac           181
# Lincoln           160
# Land Rover        139
# Porsche           136
# Oldsmobile        132
# Saab              109
# Aston Martin       91
# Bentley            74
# Plymouth           71
# Ferrari            69
# FIAT               62
# Scion              60
# Maserati           55
# Lamborghini        52
# Rolls-Royce        31
# Lotus              28
# Tesla              18
# ...

# %%
df['Make'].mode()
# Out:
# 0    Chevrolet
# Name: Make, dtype: object

# %%
df['Make'].value_counts().head(10)
# Out:
# Make
# Chevrolet     1083
# Ford           824
# Toyota         716
# Volkswagen     568
# Nissan         551
# Dodge          528
# GMC            482
# Honda          433
# Mazda          412
# Cadillac       396
# Name: count, dtype: int64

# %%
df.Make.mode()
# Out:
# 0    Chevrolet
# Name: Make, dtype: object

# %%
df.Make.mode()[0]
# Out:
# 'Chevrolet'

# %%
df.MSRP.mean()
# Out:
# np.float64(41933.28595676255)

# %%
df['MSRP'].mean()
# Out:
# np.float64(41933.28595676255)

# %%
df.MSRP.max()
# Out:
# 2065902

# %%
df[df['MSRP'] == df.MSRP.max()]
# Out:
#           Make        Model  Year             Engine Fuel Type  Engine HP  \
# 11362  Bugatti  Veyron 16.4  2008  premium unleaded (required)     1001.0
#
#        Engine Cylinders Transmission Type    Driven_Wheels  Number of Doors  \
# 11362              16.0  AUTOMATED_MANUAL  all wheel drive              2.0
#
#       Vehicle Size Vehicle Style  highway MPG  city mpg  Popularity     MSRP
# 11362      Compact         Coupe           14         8         820  2065902

# %%
df.sort_values('MSRP', ascending=False).head(1)
# Out:
#           Make        Model  Year             Engine Fuel Type  Engine HP  \
# 11362  Bugatti  Veyron 16.4  2008  premium unleaded (required)     1001.0
#
#        Engine Cylinders Transmission Type    Driven_Wheels  Number of Doors  \
# 11362              16.0  AUTOMATED_MANUAL  all wheel drive              2.0
#
#       Vehicle Size Vehicle Style  highway MPG  city mpg  Popularity     MSRP
# 11362      Compact         Coupe           14         8         820  2065902

# %%
df.nlargest(1, 'MSRP')
# Out:
#           Make        Model  Year             Engine Fuel Type  Engine HP  \
# 11362  Bugatti  Veyron 16.4  2008  premium unleaded (required)     1001.0
#
#        Engine Cylinders Transmission Type    Driven_Wheels  Number of Doors  \
# 11362              16.0  AUTOMATED_MANUAL  all wheel drive              2.0
#
#       Vehicle Size Vehicle Style  highway MPG  city mpg  Popularity     MSRP
# 11362      Compact         Coupe           14         8         820  2065902

# %%
df.loc[df.MSRP.idxmax()]
# Out:
# Make                                     Bugatti
# Model                                Veyron 16.4
# Year                                        2008
# Engine Fuel Type     premium unleaded (required)
# Engine HP                                 1001.0
# Engine Cylinders                            16.0
# Transmission Type               AUTOMATED_MANUAL
# Driven_Wheels                    all wheel drive
# Number of Doors                              2.0
# Vehicle Size                             Compact
# Vehicle Style                              Coupe
# highway MPG                                   14
# city mpg                                       8
# Popularity                                   820
# MSRP                                     2065902
# Name: 11362, dtype: object

# %%
df.groupby('Make')['MSRP'].mean()
# Out:
# Make
# Acura            3.508749e+04
# Alfa Romeo       6.160000e+04
# Aston Martin     1.981235e+05
# Audi             5.457412e+04
# BMW              6.216256e+04
# Bentley          2.471693e+05
# Bugatti          1.757224e+06
# Buick            2.903419e+04
# Cadillac         5.636827e+04
# Chevrolet        2.907473e+04
# Chrysler         2.672296e+04
# Dodge            2.490034e+04
# FIAT             2.267024e+04
# Ferrari          2.382188e+05
# Ford             2.850811e+04
# GMC              3.244409e+04
# Genesis          4.661667e+04
# HUMMER           3.646441e+04
# Honda            2.665515e+04
# Hyundai          2.492626e+04
# Infiniti         4.264027e+04
# Kia              2.551376e+04
# Lamborghini      3.315673e+05
# Land Rover       6.806709e+04
# Lexus            4.754907e+04
# Lincoln          4.386082e+04
# Lotus            6.837714e+04
# Maserati         1.136845e+05
# Maybach          5.462219e+05
# Mazda            2.041662e+04
# McLaren          2.398050e+05
# ...

# %%
df.groupby('Make')['MSRP'].mean().sort_values(ascending=False)
# Out:
# Make
# Bugatti          1.757224e+06
# Maybach          5.462219e+05
# Rolls-Royce      3.511306e+05
# Lamborghini      3.315673e+05
# Bentley          2.471693e+05
# McLaren          2.398050e+05
# Ferrari          2.382188e+05
# Spyker           2.149900e+05
# Aston Martin     1.981235e+05
# Maserati         1.136845e+05
# Porsche          1.016224e+05
# Tesla            8.525556e+04
# Mercedes-Benz    7.206953e+04
# Lotus            6.837714e+04
# Land Rover       6.806709e+04
# BMW              6.216256e+04
# Alfa Romeo       6.160000e+04
# Cadillac         5.636827e+04
# Audi             5.457412e+04
# Lexus            4.754907e+04
# Genesis          4.661667e+04
# Lincoln          4.386082e+04
# Infiniti         4.264027e+04
# HUMMER           3.646441e+04
# Acura            3.508749e+04
# GMC              3.244409e+04
# Volvo            2.972468e+04
# Chevrolet        2.907473e+04
# Buick            2.903419e+04
# Volkswagen       2.897852e+04
# Nissan           2.892115e+04
# ...

# %%
df.groupby('Make')['MSRP'].mean().sort_values(ascending=False).round(1)
# Out:
# Make
# Bugatti          1757223.7
# Maybach           546221.9
# Rolls-Royce       351130.6
# Lamborghini       331567.3
# Bentley           247169.3
# McLaren           239805.0
# Ferrari           238218.8
# Spyker            214990.0
# Aston Martin      198123.5
# Maserati          113684.5
# Porsche           101622.4
# Tesla              85255.6
# Mercedes-Benz      72069.5
# Lotus              68377.1
# Land Rover         68067.1
# BMW                62162.6
# Alfa Romeo         61600.0
# Cadillac           56368.3
# Audi               54574.1
# Lexus              47549.1
# Genesis            46616.7
# Lincoln            43860.8
# Infiniti           42640.3
# HUMMER             36464.4
# Acura              35087.5
# GMC                32444.1
# Volvo              29724.7
# Chevrolet          29074.7
# Buick              29034.2
# Volkswagen         28978.5
# Nissan             28921.2
# Toyota             28836.0
# Ford               28508.1
# Saab               27879.8
# ...

# %%
df.groupby('Make')['MSRP'].mean().sort_values(ascending=False).round(1).head(10)
# Out:
# Make
# Bugatti         1757223.7
# Maybach          546221.9
# Rolls-Royce      351130.6
# Lamborghini      331567.3
# Bentley          247169.3
# McLaren          239805.0
# Ferrari          238218.8
# Spyker           214990.0
# Aston Martin     198123.5
# Maserati         113684.5
# Name: MSRP, dtype: float64

# %%
df.groupby('Make')['Engine HP'].mean().sort_values(ascending=False).round(2).head(5)
# Out:
# Make
# Bugatti        1001.00
# Lamborghini     614.08
# McLaren         610.40
# Maybach         590.50
# Bentley         533.85
# Name: Engine HP, dtype: float64

# %%
df['Make'].value_counts().head(10).plot(kind='bar')
# Out:
# <Axes: xlabel='Make'>

# %%
df['Make'].value_counts().head(10).plot(kind='bar')
plt.show()

# %%
df.MSRP.plot(kind='hist')
plt.show()

# %%
df.Make.value_counts().head(5)
# Out:
# Make
# Chevrolet     1083
# Ford           824
# Toyota         716
# Volkswagen     568
# Nissan         551
# Name: count, dtype: int64

# %%
df['Vehicle Size'].mode()
# Out:
# 0    Compact
# Name: Vehicle Size, dtype: object

# %%
df['Vehicle Size'].value_counts().head(5)
# Out:
# Vehicle Size
# Compact    4393
# Midsize    4118
# Large      2683
# Name: count, dtype: int64

# %%
df['Transmission Type'].mode()
# Out:
# 0    AUTOMATIC
# Name: Transmission Type, dtype: object

# %%
df['Transmission Type'].value_counts().head(5)
# Out:
# Transmission Type
# AUTOMATIC           7928
# MANUAL              2633
# AUTOMATED_MANUAL     553
# DIRECT_DRIVE          68
# UNKNOWN               12
# Name: count, dtype: int64
